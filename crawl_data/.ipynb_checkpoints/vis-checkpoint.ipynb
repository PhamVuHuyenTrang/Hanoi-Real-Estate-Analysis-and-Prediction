# %%
import pandas as pd
from matplotlib import pyplot as plt
import folium

# %%
data = pd.read_csv("final.csv")
data.head()
# Out:
#    index House Direction Balcony Direction Bedrooms Toilets           Legits  \
# 0      0             Nam               Bắc        3       2             None
# 1      1             Nam               Bắc        2       2   Sổ đỏ/ Sổ hồng
# 2      2            None              None        3       3   Sổ đỏ/ Sổ hồng
# 3      3            None              None        5    None  Sổ đỏ/ Sổ hồng.
# 4      4            None              None        3       2   Sổ đỏ/ Sổ hồng
#
#   Floors Facade Entrance     District               Ward  \
# 0   None   None     None       Tây Hồ  Phường Phú Thượng
# 1   None   None     None       Tây Hồ  Phường Phú Thượng
# 2   None   None     None     Cầu Giấy     Phường Yên Hòa
# 3      5   None     None    Long Biên       Phường Bồ Đề
# 4   None   None     None  Nam Từ Liêm  Thị trấn Cầu Diễn
#
#                   Street   Area     Price
# 0                   None  100.0  4000.000
# 1      Đường Võ Chí Công  80.74  3496.042
# 2  Đường Dương Đình Nghệ  131.0  5900.000
# 3            Đường Bồ Đề   52.0  6750.000
# 4         Đường Hàm Nghi  119.0  5800.000

# %%
import folium

world_map = folium.Map()

# %%
for i in data.columns:
    print(i)
# Out:
# index
# House Direction
# Balcony Direction
# Bedrooms
# Toilets
# Legits
# Floors
# Facade
# Entrance
# District
# Ward
# Street
# Area
# Price

# %%
(data["Price"] == "None").sum()
# Out:
# 0

# %%
pd.DataFrame(data["Price"].describe())
# Out:
#               Price
# count  4.996600e+04
# mean   1.077416e+05
# std    1.209828e+06
# min    1.020000e+01
# 25%    4.500000e+03
# 50%    1.800000e+04
# 75%    7.000000e+04
# max    2.300000e+08

# %%
price = data["Price"]
price = price[price <2.3e8]

# %%
price.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
IQR = data.Price.quantile(0.75) - data.Price.quantile(0.25)
Lower_fence = data.Price.quantile(0.25) - (IQR * 3)
Upper_fence = data.Price.quantile(0.75) + (IQR * 3)

# %%
price = price[(price >= Lower_fence) & (price <= Upper_fence)]
price
# Out:
# 0         4000.000
# 1         3496.042
# 2         5900.000
# 3         6750.000
# 4         5800.000
#            ...
# 49961    48000.000
# 49962    65000.000
# 49963    43000.000
# 49964    76000.000
# 49965    68000.000
# Name: Price, Length: 46337, dtype: float64

# %%
price.describe()
# Out:
# count     46337.000000
# mean      40216.844116
# std       54677.500618
# min          10.200000
# 25%        4200.000000
# 50%       13600.000000
# 75%       55000.000000
# max      266000.000000
# Name: Price, dtype: float64

# %%
price.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
plt.violinplot(price)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2dc2bec1ed0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2dc2bec1e40>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2dc2bec2590>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2dc2bec2950>}

# %%
price.plot(kind="hist", bins=200, figsize=(10,5), title="Price (million vnd)")
# Out:
# <AxesSubplot:title={'center':'Price (million vnd)'}, ylabel='Frequency'>

# %%
d = lambda x: x.replace("-", "")
n = lambda x: x if x == "None" or int(x) <= 10 else "10+"

# %%
data['House Direction'] = data['House Direction'].apply(d)

# %%
data['Balcony Direction'] = data['Balcony Direction'].apply(d)

# %%
features = ['House Direction', 'Balcony Direction', 'Bedrooms', 'Toilets', 'Floors','District']

for feature in features:
    data[feature].value_counts().sort_values(ascending=True).plot(kind="barh", figsize=(15,10), title=feature)
    plt.show()
