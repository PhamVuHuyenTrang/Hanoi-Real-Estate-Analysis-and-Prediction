# %%
import pandas as pd
import numpy

# %%
files = ["alo.csv", "bds_com.csv", "home.csv", "bds_so"]

# %%
data = pd.read_csv("bds_com.csv")
data.head()
# Out:
#                            id        date    exp_date house_direction  \
# 0  batdongsan_com_vn_35339744  25/11/2022  05/12/2022             Nam
# 1  batdongsan_com_vn_35747475  28/11/2022  08/12/2022             Nam
# 2  batdongsan_com_vn_35981012  29/11/2022  06/12/2022            None
# 3  batdongsan_com_vn_35968324  28/11/2022  08/12/2022            None
# 4  batdongsan_com_vn_35957404  26/11/2022  03/12/2022            None
#
#   balcony_direction bedroom toilet            legit  \
# 0               Bắc       3      2             None
# 1               Bắc       2      2   Sổ đỏ/ Sổ hồng
# 2              None       3      3   Sổ đỏ/ Sổ hồng
# 3              None       5   None  Sổ đỏ/ Sổ hồng.
# 4              None       3      2   Sổ đỏ/ Sổ hồng
#
#                                            furniture floor facade entrance  \
# 0                                                NaN  None   None     None
# 1                                                NaN  None   None     None
# 2                                             Đầy đủ  None   None     None
# 3                                            Cơ bản.     5   None     None
# 4  Nội thất đầy đủ: Thiết bị điện tử(tivi, tủ lạn...  None   None     None
#
#      city     district               ward                 street    area  \
# 0  Hà Nội       Tây Hồ  Phường Phú Thượng                   None  100.00
# 1  Hà Nội       Tây Hồ  Phường Phú Thượng      Đường Võ Chí Công   80.74
# 2  Hà Nội     Cầu Giấy     Phường Yên Hòa  Đường Dương Đình Nghệ  131.00
# 3  Hà Nội    Long Biên       Phường Bồ Đề            Đường Bồ Đề   52.00
# 4  Hà Nội  Nam Từ Liêm  Thị trấn Cầu Diễn         Đường Hàm Nghi  119.00
#
#       price
# 0  4000.000
# 1  3496.042
# 2  5900.000
# 3  6750.000
# 4  5800.000

# %%
data = data[data["district"] != "Hà Nội. 73m²* 5.4 tỷ. Nhà đẹp siêu vip"]

# %%
data = data[data["district"] != "Hà Nội. 76m²* 5T 5.95 tỷ. Nhà đẹp siêu vip"]

# %%
data.reset_index(inplace=True)

# %%
data = data.drop(["index"], axis=1)

# %%
data.head()
# Out:
#                            id        date    exp_date house_direction  \
# 0  batdongsan_com_vn_35339744  25/11/2022  05/12/2022             Nam
# 1  batdongsan_com_vn_35747475  28/11/2022  08/12/2022             Nam
# 2  batdongsan_com_vn_35981012  29/11/2022  06/12/2022            None
# 3  batdongsan_com_vn_35968324  28/11/2022  08/12/2022            None
# 4  batdongsan_com_vn_35957404  26/11/2022  03/12/2022            None
#
#   balcony_direction bedroom toilet            legit  \
# 0               Bắc       3      2             None
# 1               Bắc       2      2   Sổ đỏ/ Sổ hồng
# 2              None       3      3   Sổ đỏ/ Sổ hồng
# 3              None       5   None  Sổ đỏ/ Sổ hồng.
# 4              None       3      2   Sổ đỏ/ Sổ hồng
#
#                                            furniture floor facade entrance  \
# 0                                                NaN  None   None     None
# 1                                                NaN  None   None     None
# 2                                             Đầy đủ  None   None     None
# 3                                            Cơ bản.     5   None     None
# 4  Nội thất đầy đủ: Thiết bị điện tử(tivi, tủ lạn...  None   None     None
#
#      city     district               ward                 street    area  \
# 0  Hà Nội       Tây Hồ  Phường Phú Thượng                   None  100.00
# 1  Hà Nội       Tây Hồ  Phường Phú Thượng      Đường Võ Chí Công   80.74
# 2  Hà Nội     Cầu Giấy     Phường Yên Hòa  Đường Dương Đình Nghệ  131.00
# 3  Hà Nội    Long Biên       Phường Bồ Đề            Đường Bồ Đề   52.00
# 4  Hà Nội  Nam Từ Liêm  Thị trấn Cầu Diễn         Đường Hàm Nghi  119.00
#
#       price
# 0  4000.000
# 1  3496.042
# 2  5900.000
# 3  6750.000
# 4  5800.000

# %%
home = pd.read_csv("home.csv")

# %%
so = pd.read_csv("combined_csv.csv")
so.head()
# Out:
#    Unnamed: 0   Price   Area  Facade  Building Line Floors Bedrooms  \
# 0           0   63000   45.0     4.0           10.0      4        5
# 1           1  198000  100.0     5.0           30.0      4        5
# 2           2   98000   27.0     5.0           20.0      3        3
# 3           4  120000   95.0     5.0            4.0      5        4
# 4           5   42000  112.0    11.0            2.0   None        3
#
#   Pulish Time        Type                                       ID Toilets  \
# 0  08/11/2022  Tin thường   batdongsan_so_com_vn_1670468631.269085    None
# 1  08/11/2022  Tin thường  batdongsan_so_com_vn_1670468633.5936205       4
# 2  08/11/2022  Tin thường  batdongsan_so_com_vn_1670468636.2328222       2
# 3  08/11/2022  Tin thường   batdongsan_so_com_vn_1670468641.770186       3
# 4  08/11/2022  Tin thường  batdongsan_so_com_vn_1670468644.3474865       2
#
#   Direction     District
# 0       NaN  Nam Từ Liêm
# 1       NaN      Gia Lâm
# 2   Tây nam       Tây Hồ
# 3       NaN    Long Biên
# 4       Nam  Nam Từ Liêm

# %%
bdscom = pd.read_csv("bds_com.csv")

# %%
home = pd.read_csv("data_fo_vs.csv")

# %%
bdsso = pd.read_csv("bds_so.csv")

# %%
alo = pd.read_csv("alo.csv")

# %%
bdscom.columns
# Out:
# Index(['House Direction', 'Balcony Direction', 'Bedrooms', 'Toilets', 'Legits',
#        'Furnitures', 'Floors', 'Facade', 'Entrance', 'City', 'District',
#        'Ward', 'Street', 'Area', 'Price'],
#       dtype='object')

# %%
home.columns
# Out:
# Index(['Unnamed: 0', 'Price', 'Area', 'Mặt tiền', 'Số phòng ngủ',
#        'Hướng ban công', 'Tình trạng pháp lý', 'Hướng nhà', 'Số tầng',
#        'Bồn cầu', 'City', 'District', 'Name'],
#       dtype='object')

# %%
home = home[['Area', 'Mặt tiền', 'Số phòng ngủ',
       'Hướng ban công', 'Tình trạng pháp lý', 'Hướng nhà', 'Số tầng',
       'Bồn cầu', 'City', 'District', 'Price']]

# %%
features = {'Mặt tiền': "Facade", 'Số phòng ngủ':"Bedrooms",
       'Hướng ban công': "Balcony Direction", 'Tình trạng pháp lý':"Legits", 'Hướng nhà':"House Direction"
            , 'Số tầng': "Floors",
       'Bồn cầu':"Toilets"}
home = home.rename(columns=features)

# %%
home = home.fillna("None")

# %%
alo.columns
# Out:
# Index(['Unnamed: 0', 'price', 'area', 'Hướng', 'Phòng ăn', 'Đường trước nhà',
#        'Nhà bếp', 'Loại BDS', 'Pháp lý', 'Sân thượng', 'Số lầu',
#        'Chổ để xe hơi', 'Số phòng ngủ', 'Chính chủ', 'city', 'district',
#        'ward', 'street'],
#       dtype='object')

# %%
alo = alo[['price', 'area', 'Hướng',
       'Đường trước nhà', 'Pháp lý',
        'Số lầu', 'Số phòng ngủ','district',
       'ward', 'street']]

# %%
alo = alo.rename(columns={'price':"Price", 'area':"Area", 'Hướng':"House Direction",
       'Đường trước nhà': "Facade", 'Pháp lý':"Legits",
        'Số lầu':"Floors", 'Số phòng ngủ':"Bedrooms", 'district':"District",
       'ward':"Ward", 'street':"Street"})

# %%
alo = alo[alo["Price"] != "None"]

# %%
bdsso.columns
# Out:
# Index(['Unnamed: 0', 'Price', 'Area', 'Facade', 'Building Line', 'Floors',
#        'Bedrooms', 'Pulish Time', 'Type', 'ID', 'Toilets', 'Direction',
#        'District'],
#       dtype='object')

# %%
bdsso = bdsso[['Price', 'Area', 'Facade',  'Floors',
       'Bedrooms', 'Toilets', 'Direction',
       'District']]

# %%
bdsso = bdsso.rename({"Direction":"House Direction"}, axis=1)
bdsso.head()
# Out:
#      Price   Area  Facade Floors Bedrooms Toilets House Direction     District
# 0   6300.0   45.0     4.0      4        5    None             NaN  Nam Từ Liêm
# 1  19800.0  100.0     5.0      4        5       4             NaN      Gia Lâm
# 2   9800.0   27.0     5.0      3        3       2         Tây nam       Tây Hồ
# 3  12000.0   95.0     5.0      5        4       3             NaN    Long Biên
# 4   4200.0  112.0    11.0   None        3       2             Nam  Nam Từ Liêm

# %%
bdsso = bdsso.fillna("None")

# %%
final = pd.concat([bdscom, home, bdsso, alo]).reset_index()
final.head()
# Out:
#    index House Direction Balcony Direction Bedrooms Toilets           Legits  \
# 0      0             Nam               Bắc        3       2             None
# 1      1             Nam               Bắc        2       2   Sổ đỏ/ Sổ hồng
# 2      2            None              None        3       3   Sổ đỏ/ Sổ hồng
# 3      3            None              None        5    None  Sổ đỏ/ Sổ hồng.
# 4      4            None              None        3       2   Sổ đỏ/ Sổ hồng
#
#                                           Furnitures Floors Facade Entrance  \
# 0                                                NaN   None   None     None
# 1                                                NaN   None   None     None
# 2                                             Đầy đủ   None   None     None
# 3                                            Cơ bản.      5   None     None
# 4  Nội thất đầy đủ: Thiết bị điện tử(tivi, tủ lạn...   None   None     None
#
#      City     District               Ward                 Street   Area  \
# 0  Hà Nội       Tây Hồ  Phường Phú Thượng                   None  100.0
# 1  Hà Nội       Tây Hồ  Phường Phú Thượng      Đường Võ Chí Công  80.74
# 2  Hà Nội     Cầu Giấy     Phường Yên Hòa  Đường Dương Đình Nghệ  131.0
# 3  Hà Nội    Long Biên       Phường Bồ Đề            Đường Bồ Đề   52.0
# 4  Hà Nội  Nam Từ Liêm  Thị trấn Cầu Diễn         Đường Hàm Nghi  119.0
#
#       Price
# 0    4000.0
# 1  3496.042
# 2    5900.0
# 3    6750.0
# 4    5800.0

# %%
final = final.drop(['Furnitures'], axis=1)

# %%
final.isnull().mean()
# Out:
# index                0.000000
# House Direction      0.000000
# Balcony Direction    0.536117
# Bedrooms             0.000000
# Toilets              0.422570
# Legits               0.113547
# Floors               0.000000
# Facade               0.000000
# Entrance             0.571815
# City                 0.536117
# District             0.000000
# Ward                 0.149245
# Street               0.149245
# Area                 0.000000
# Price                0.000000
# dtype: float64

# %%
final = final.fillna("None")

# %%
final.isnull().mean()
# Out:
# index                0.0
# House Direction      0.0
# Balcony Direction    0.0
# Bedrooms             0.0
# Toilets              0.0
# Legits               0.0
# Floors               0.0
# Facade               0.0
# Entrance             0.0
# City                 0.0
# District             0.0
# Ward                 0.0
# Street               0.0
# Area                 0.0
# Price                0.0
# dtype: float64

# %%
final.drop(["index"], axis=1)
# Out:
#       House Direction Balcony Direction Bedrooms Toilets           Legits  \
# 0                 Nam               Bắc        3       2             None
# 1                 Nam               Bắc        2       2   Sổ đỏ/ Sổ hồng
# 2                None              None        3       3   Sổ đỏ/ Sổ hồng
# 3                None              None        5    None  Sổ đỏ/ Sổ hồng.
# 4                None              None        3       2   Sổ đỏ/ Sổ hồng
# ...               ...               ...      ...     ...              ...
# 50221            None              None        4    None   Sổ hồng/ Sổ đỏ
# 50222            None              None        4    None   Sổ hồng/ Sổ đỏ
# 50223            None              None        4    None   Sổ hồng/ Sổ đỏ
# 50224            None              None        4    None             None
# 50225            None              None        4    None   Sổ hồng/ Sổ đỏ
#
#       Floors Facade Entrance    City          District                  Ward  \
# 0       None   None     None  Hà Nội            Tây Hồ     Phường Phú Thượng
# 1       None   None     None  Hà Nội            Tây Hồ     Phường Phú Thượng
# 2       None   None     None  Hà Nội          Cầu Giấy        Phường Yên Hòa
# 3          5   None     None  Hà Nội         Long Biên          Phường Bồ Đề
# 4       None   None     None  Hà Nội       Nam Từ Liêm     Thị trấn Cầu Diễn
# ...      ...    ...      ...     ...               ...                   ...
# 50221      4    3.0     None    None   Quận Thanh Xuân    Phường Thượng Đình
# 50222      5    3.0     None    None   Quận Thanh Xuân   Phường Khương Trung
# 50223      4    3.0     None    None      Quận Đống Đa      Phường Láng Hạ
# 50224      5    3.0     None    None      Quận Đống Đa      Phường Cát Linh
# 50225      4    3.0     None    None      Quận Đống Đa      Phường Cát Linh
#
#                       Street   Area     Price
# 0                       None  100.0    4000.0
# 1          Đường Võ Chí Công  80.74  3496.042
# 2      Đường Dương Đình Nghệ  131.0    5900.0
# 3                Đường Bồ Đề   52.0    6750.0
# 4             Đường Hàm Nghi  119.0    5800.0
# ...                      ...    ...       ...
# 50221      Đường Nguyễn Trãi   54.0     48000
# 50222     Đường Khương Trung   75.0     65000
# 50223             Đường Láng   40.0     43000
# 50224            Phố Hào Nam   42.0     76000
# 50225            Phố Hào Nam   50.0     68000
#
# [50226 rows x 14 columns]

# %%
final = final.drop(columns=["City"])

# %%
final = final[final["Price"] != "None"]

# %%
final = final[final["Price"] != "Thỏa thuận"]

# %%
final["Price"] = final["Price"].apply(lambda x: float(x if  not isinstance(x, str) else x.replace(",", ".")))

# %%
pd.to_numeric(final["Price"])
# Out:
# 0         4000.000
# 1         3496.042
# 2         5900.000
# 3         6750.000
# 4         5800.000
#            ...
# 50221    48000.000
# 50222    65000.000
# 50223    43000.000
# 50224    76000.000
# 50225    68000.000
# Name: Price, Length: 50049, dtype: float64

# %%
final = final[final["Price"] > 10]

# %%
final.to_csv("final.csv", index=False)
